# %% [markdown]
# ## 라이브러리 설치

# %%
# 관련 라이브러리 설치
# [참고] 맨 처음 한 번만 실행
# !pip install pandas openpyxl xlrd bs4 kiwipiepy nltk scikit_learn seaborn wordcloud gensim pyldavis
# Out:
# ...
#      ---------------------------------------- 0.0/34.7 MB ? eta -:--:--
#      - -------------------------------------- 1.6/34.7 MB 33.1 MB/s eta 0:00:02
#      ----- ---------------------------------- 4.6/34.7 MB 48.5 MB/s eta 0:00:01
#      -------- ------------------------------- 7.8/34.7 MB 62.3 MB/s eta 0:00:01
#      ------------ -------------------------- 10.7/34.7 MB 81.8 MB/s eta 0:00:01
#      -------------- ------------------------ 12.9/34.7 MB 59.8 MB/s eta 0:00:01
#      ----------------- --------------------- 15.6/34.7 MB 65.2 MB/s eta 0:00:01
#      ---------------------- ---------------- 20.0/34.7 MB 65.2 MB/s eta 0:00:01
#      -------------------------- ------------ 23.3/34.7 MB 81.8 MB/s eta 0:00:01
#      ------------------------------ -------- 27.1/34.7 MB 81.8 MB/s eta 0:00:01
#      --------------------------------- ----- 29.5/34.7 MB 72.6 MB/s eta 0:00:01
#      --------------------------------- ----- 29.7/34.7 MB 54.7 MB/s eta 0:00:01
# ...

# %%
# 설치한 라이브러리 목록 확인
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.4.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     24.1.0
# Babel                     2.15.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# bs4                       0.0.2
# certifi                   2024.7.4
# cffi                      1.16.0
# charset-normalizer        3.3.2
# click                     8.1.7
# comm                      0.2.2
# contourpy                 1.2.1
# cycler                    0.12.1
# debugpy                   1.8.3
# decorator                 5.1.1
# defusedxml                0.7.1
# et-xmlfile                1.1.0
# executing                 2.0.1
# fastjsonschema            2.20.0
# fonttools                 4.53.1
# ...

# %% [markdown]
# ## End of Document
